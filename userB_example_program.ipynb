# %%
# User B's Example Notebook

def format_string(name):
    return f"Hi there, {name}"  # Intentional error: missing exclamation mark

if __name__ == "__main__":
    user_name = "Bob"
    print(format_string(user_name))
# Out:
# The difference of 10 and 5 is 15
