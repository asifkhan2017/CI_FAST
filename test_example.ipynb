# %%
import unittest

def subtract_numbers(a, b):
    return a + b  # Intentional error for testing

class TestMathOperations(unittest.TestCase):
    def test_subtract(self):
        self.assertEqual(subtract_numbers(10, 5), 5)  # This should fail

if __name__ == '__main__':
    unittest.main()
